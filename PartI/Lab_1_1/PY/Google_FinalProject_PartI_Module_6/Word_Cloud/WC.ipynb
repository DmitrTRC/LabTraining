# %%
# Here are all the installs and imports you will need for your word cloud script and uploader widget

# !pip install wordcloud
# !pip install fileupload
# !pip install ipywidgets
# !jupyter nbextension install --py --user fileupload
# !jupyter nbextension enable --py fileupload


import numpy as np
import wordcloud
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys
# Out:
# Requirement already satisfied: wordcloud in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from wordcloud) (1.21.4)
# Requirement already satisfied: matplotlib in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/dmitrymorozov/PycharmProjects/LabTraining/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: fileupload in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (0.1.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from fileupload) (5.1.1)
# Requirement already satisfied: notebook>=4.2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from fileupload) (6.4.6)
# Requirement already satisfied: ipywidgets>=5.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from fileupload) (7.6.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets>=5.1->fileupload) (7.30.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets>=5.1->fileupload) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets>=5.1->fileupload) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets>=5.1->fileupload) (1.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets>=5.1->fileupload) (6.6.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (7.1.0)
# Requirement already satisfied: appnope in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (3.0.24)
# Requirement already satisfied: pygments in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (57.0.0)
# Requirement already satisfied: pickleshare in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (4.8.0)
# Requirement already satisfied: decorator in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (5.1.0)
# Requirement already satisfied: backcall in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.8.3)
# Requirement already satisfied: entrypoints in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.3)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (4.9.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.5.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=5.1->fileupload) (4.2.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.1->fileupload) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.1->fileupload) (0.18.0)
# Requirement already satisfied: nbconvert in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.2->fileupload) (6.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.2->fileupload) (0.12.1)
# Requirement already satisfied: prometheus-client in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.2->fileupload) (0.12.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.2->fileupload) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.2->fileupload) (21.3.0)
# Requirement already satisfied: jinja2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.2->fileupload) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.2->fileupload) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (1.15.0)
# Requirement already satisfied: pycparser in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.2->fileupload) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jinja2->notebook>=4.2->fileupload) (2.0.1)
# Requirement already satisfied: testpath in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.2->fileupload) (0.5.0)
# Requirement already satisfied: bleach in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.2->fileupload) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.2->fileupload) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.2->fileupload) (0.5.9)
# Requirement already satisfied: defusedxml in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.2->fileupload) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.2->fileupload) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.2->fileupload) (0.1.2)
# Requirement already satisfied: packaging in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.2->fileupload) (21.3)
# Requirement already satisfied: webencodings in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.2->fileupload) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.2->fileupload) (3.0.6)
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/dmitrymorozov/PycharmProjects/LabTraining/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: ipywidgets in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (7.6.5)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets) (7.30.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets) (6.6.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: appnope in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: setuptools>=18.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (57.0.0)
# Requirement already satisfied: decorator in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.0)
# Requirement already satisfied: pickleshare in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.24)
# Requirement already satisfied: pygments in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.10.0)
# Requirement already satisfied: backcall in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: entrypoints in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (4.2.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: nbconvert in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.1)
# Requirement already satisfied: argon2-cffi in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: prometheus-client in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.0)
# Requirement already satisfied: jinja2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: argon2-cffi-bindings in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: testpath in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.9)
# Requirement already satisfied: bleach in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: webencodings in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.6)
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/dmitrymorozov/PycharmProjects/LabTraining/venv/bin/python -m pip install --upgrade pip' command.
# Installing /Users/dmitrymorozov/PycharmProjects/LabTraining/venv/lib/python3.9/site-packages/fileupload/static -> fileupload
# Up to date: /Users/dmitrymorozov/Library/Jupyter/nbextensions/fileupload/widget.js
# Up to date: /Users/dmitrymorozov/Library/Jupyter/nbextensions/fileupload/extension.js
# Up to date: /Users/dmitrymorozov/Library/Jupyter/nbextensions/fileupload/fileupload/widget.js
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable fileupload --user --py
#
# Enabling notebook extension fileupload/extension...
#       - Validating: OK

# %%
def _upload():
    _upload_widget = fileupload.FileUploadWidget()

    def _cb(change):
        global file_contents
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} kB)'.format(
            filename, len(decoded.read()) / 2 ** 10))
        file_contents = decoded.getvalue()

    _upload_widget.observe(_cb, names='data')
    display(_upload_widget)


_upload()
# Out:
# FileUploadWidget(label='Browse', _dom_classes=('widget_item', 'btn-group'))
